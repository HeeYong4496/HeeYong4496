# %%
import warnings
warnings.filterwarnings('ignore')
from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %%
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
# 정규화
train_images = train_images.astype('float32') /255
test_images = test_images.astype('float32') /255

# %%
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# modeling
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout
from keras.layers.normalization import BatchNormalization

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), padding='same', input_shape=(32,32,3), activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=2))

model.add(Dropout(0.2))

# %%
model.add(Conv2D(64, kernel_size=(3,3), padding='same',  activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3,3), padding='same',activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=2))

model.add(Dropout(0.3))

# %%
model.add(Conv2D(128, kernel_size=(3,3), padding='same',  activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3,3), padding='same',activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=2))

model.add(Dropout(0.4))

# %%
model.add(Flatten())

# %%
model.add(Dense(512, activation='relu'))

# %%
model.add(Dense(10, activation='softmax'))

# %%
from keras.optimizers import Adam
optimizer = Adam(lr=0.01)

# %%
model.compile(optimizer=optimizer, loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,343,018
# Trainable params: 1,342,122
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.fit(train_images, train_labels, epochs=20, batch_size=200)
# Out:
# Epoch 1/20
# 250/250 [==============================] - 7s 22ms/step - loss: 7.1327 - accuracy: 0.2504
# Epoch 2/20
# 250/250 [==============================] - 6s 23ms/step - loss: 1.5814 - accuracy: 0.4160
# Epoch 3/20
# 250/250 [==============================] - 6s 23ms/step - loss: 1.3764 - accuracy: 0.5025
# Epoch 4/20
# 250/250 [==============================] - 6s 22ms/step - loss: 1.1666 - accuracy: 0.5821
# Epoch 5/20
# 250/250 [==============================] - 6s 23ms/step - loss: 1.0117 - accuracy: 0.6463
# Epoch 6/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.9035 - accuracy: 0.6800
# Epoch 7/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.7876 - accuracy: 0.7237
# Epoch 8/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.7061 - accuracy: 0.7554
# Epoch 9/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.6398 - accuracy: 0.7763
# Epoch 10/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.6145 - accuracy: 0.7863
# Epoch 11/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.5684 - accuracy: 0.8019
# Epoch 12/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.5369 - accuracy: 0.8133
# Epoch 13/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.5115 - accuracy: 0.8240
# Epoch 14/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4911 - accuracy: 0.8289
# Epoch 15/20
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4780 - accuracy: 0.8348
# Epoch 16/20
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4691 - accuracy: 0.8370
# Epoch 17/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4490 - accuracy: 0.8444
# Epoch 18/20
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4274 - accuracy: 0.8521
# Epoch 19/20
# 250/250 [==============================] - 5s 22ms/step - loss: 0.4207 - accuracy: 0.8576
# Epoch 20/20
# 250/250 [==============================] - 6s 22ms/step - loss: 0.4093 - accuracy: 0.8576

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5331 - accuracy: 0.8231

# %%
print('test_acc:', test_acc)
# Out:
# test_acc: 0.8230999708175659

# %%
import os
if not os.path.exists('./model')
    os.mkdir('model')
# Out:
#   File "<ipython-input-40-a0725937176a>", line 2
#     if not os.path.exists('./model')
#                                     ^
# SyntaxError: invalid syntax

# %%
model.save('model/model_cifar10.h5')
